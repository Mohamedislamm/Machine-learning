# %%
import numpy as np
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
def generate_data(num_samples=10000, config='both'):
    theta1 = np.random.uniform(-np.pi, np.pi, num_samples)
    theta2 = np.random.uniform(-np.pi, np.pi, num_samples)

    l1, l2 = 10.0, 7.0
    x = l1 * np.cos(theta1) + l2 * np.cos(theta1 + theta2)
    y = l1 * np.sin(theta1) + l2 * np.sin(theta1 + theta2)

    if config == 'up':
        mask = theta2 >= 0
    elif config == 'down':
        mask = theta2 < 0
    else:
        mask = np.ones_like(theta2, dtype=bool)

    X = np.column_stack([x, y])[mask]
    y = np.column_stack([theta1, theta2])[mask]

    return X, y

X, y = generate_data(10000, 'up')

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

scaler_X = StandardScaler()
scaler_y = StandardScaler()

X_train_scaled = scaler_X.fit_transform(X_train)
X_test_scaled = scaler_X.transform(X_test)
y_train_scaled = scaler_y.fit_transform(y_train)
y_test_scaled = scaler_y.transform(y_test)

model = tf.keras.Sequential([
    tf.keras.layers.Dense(64, activation='sigmoid', input_shape=(2,)),
    tf.keras.layers.Dense(32, activation='sigmoid'),
    tf.keras.layers.Dense(2)
])

model.compile(optimizer='adam', loss='mse')

model.fit(X_train_scaled, y_train_scaled, epochs=50, batch_size=32, validation_split=0.2, verbose=1)

test_loss = model.evaluate(X_test_scaled, y_test_scaled, verbose=0)
print(f"Test Loss: {test_loss:.4f}")

def predict_angles(x, y):
    input_scaled = scaler_X.transform([[x, y]])
    output_scaled = model.predict(input_scaled, verbose=0)
    angles = scaler_y.inverse_transform(output_scaled)
    return angles[0]

test_x, test_y = 12.0, 5.0
predicted_angles = predict_angles(test_x, test_y)
print(f"Angles: theta1={predicted_angles[0]:.3f}, theta2={predicted_angles[1]:.3f}")
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/50
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.9609 - val_loss: 0.9238
# Epoch 2/50
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8558 - val_loss: 0.8186
# Epoch 3/50
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.7666 - val_loss: 0.7938
# Epoch 4/50
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.7581 - val_loss: 0.7945
# Epoch 5/50
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.7277 - val_loss: 0.7864
# Epoch 6/50
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.7310 - val_loss: 0.7851
# Epoch 7/50
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.7104 - val_loss: 0.7722
# Epoch 8/50
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.7027 - val_loss: 0.7637
# Epoch 9/50
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.7105 - val_loss: 0.7457
# Epoch 10/50
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6770 - val_loss: 0.7143
# Epoch 11/50
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6441 - val_loss: 0.6827
# Epoch 12/50
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6185 - val_loss: 0.6442
# Epoch 13/50
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5704 - val_loss: 0.6083
# Epoch 14/50
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5518 - val_loss: 0.5684
# Epoch 15/50
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5274 - val_loss: 0.5279
# Epoch 16/50
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4754 - val_loss: 0.4879
# Epoch 17/50
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4408 - val_loss: 0.4225
# Epoch 18/50
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3900 - val_loss: 0.3642
# Epoch 19/50
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3174 - val_loss: 0.3109
# Epoch 20/50
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2814 - val_loss: 0.2789
# Epoch 21/50
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2433 - val_loss: 0.2490
# Epoch 22/50
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2301 - val_loss: 0.2323
# Epoch 23/50
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2152 - val_loss: 0.2198
# Epoch 24/50
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2189 - val_loss: 0.2119
# Epoch 25/50
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2050 - val_loss: 0.2032
# Epoch 26/50
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2019 - val_loss: 0.2009
# Epoch 27/50
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1896 - val_loss: 0.1931
# Epoch 28/50
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1847 - val_loss: 0.1911
# Epoch 29/50
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1806 - val_loss: 0.1832
# Epoch 30/50
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1664 - val_loss: 0.1799
# Epoch 31/50
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1654 - val_loss: 0.1791
# Epoch 32/50
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1709 - val_loss: 0.1732
# Epoch 33/50
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1534 - val_loss: 0.1722
# Epoch 34/50
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1750 - val_loss: 0.1681
# Epoch 35/50
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1463 - val_loss: 0.1647
# Epoch 36/50
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1454 - val_loss: 0.1630
# Epoch 37/50
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1405 - val_loss: 0.1627
# Epoch 38/50
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1392 - val_loss: 0.1565
# Epoch 39/50
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1306 - val_loss: 0.1559
# Epoch 40/50
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1406 - val_loss: 0.1544
# Epoch 41/50
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1459 - val_loss: 0.1511
# Epoch 42/50
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1351 - val_loss: 0.1500
# Epoch 43/50
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1369 - val_loss: 0.1538
# Epoch 44/50
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1326 - val_loss: 0.1459
# Epoch 45/50
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1368 - val_loss: 0.1446
# Epoch 46/50
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1341 - val_loss: 0.1427
# Epoch 47/50
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1354 - val_loss: 0.1405
# Epoch 48/50
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1467 - val_loss: 0.1420
# Epoch 49/50
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1382 - val_loss: 0.1366
# Epoch 50/50
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1332 - val_loss: 0.1357
# Test Loss: 0.1155
# Angles: theta1=-0.027, theta2=1.181
